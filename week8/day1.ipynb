# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Especially important this week: pull the latest</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml --prune</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Just one import to start with!!

import modal

# %% [markdown]
# # Setting up the modal tokens
#
# The first time you run this, please uncomment the next line and execute it.
# This is the same as running `modal setup` from the command line. It connects with Modal and installs your tokens.
#
# A student on Windows mentioned that on Windows, you might also need to run this command from a command prompt afterwards:
# `modal token new`
# (Thank you Ed B. for that!)
#
# And I've also heard that in some situations, you might need to restart the Kernel of this jupyter notebook after running this. (Kernel menu >> Restart Kernel and Clear Outputs of All Cells).

# %%
# Remove the '# ' from the next line and run the cell
# !modal setup
# Out:
# The web browser should have opened for you to authenticate and get an API token.
# If it didn't, please copy this URL into your web browser manually:
#
# ]8;id=751600;https://modal.com/token-flow/tf-cIcgsapWkkEHyn6IyDGj06\https://modal.com/token-flow/tf-cIcgsapWkkEHyn6IyDGj06]8;;\
#
# ⠋ Waiting for authentication in the web browser
# ⠹ Waiting for token flow to complete...omplete...
# Web authentication finished successfully!
# Token is connected to the akey7 workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
# Token written to /Users/alicia/.modal.toml in profile akey7.

# %%
from hello import app, hello

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# 'Hello from Denver, Colorado, US!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Phoenix, Arizona, US!!'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **hf-secret** because that's how we refer to it in the code
# 4. Fill in your HF_TOKEN where it prompts you
#
# ### And now back to business: time to work with Llama

# %%
from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/akey7/main/ap-kDc95lpqRr200vAkS6G3Gh
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/llama.py
# ├── 🔨 Created mount PythonPackage:hello
# └── 🔨 Created function generate.
# Output()
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading shards:  25%|██▌       | 1/4 [01:58<05:55, 118.57s/it]
# Downloading shards:  50%|█████     | 2/4 [03:57<03:57, 118.56s/it]
# Downloading shards:  75%|███████▌  | 3/4 [05:54<01:57, 117.85s/it]
# Downloading shards: 100%|██████████| 4/4 [06:21<00:00, 82.28s/it] Downloading shards: 100%|██████████| 4/4 [06:21<00:00, 95.47s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:06<00:19,  6.66s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:13<00:13,  6.78s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:20<00:06,  6.82s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:22<00:00,  4.79s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:22<00:00,  5.52s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at https://modal.com/apps/akey7/main/ap-kDc95lpqRr200vAkS6G3Gh
# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/akey7/main/ap-cbFbKxdFPSMmWfSKFGpsbK
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-4gmuRjAqSjaZbr0g87mGf3
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes peft torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.1-py3-none-any.whl.metadata (44 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.11/site-packages (from bitsandbytes) (4.12.2)
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl (336 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 234.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl (374 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 488.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 483.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 495.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 493.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 834.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 492.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 504.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 518.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 498.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 514.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 511.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 536.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 498.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 519.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.1-py3-none-any.whl (10.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 334.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 507.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 451.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 251.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 365.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 668.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.0 GB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: mpmath, urllib3, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, triton, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# Successfully installed MarkupSafe-3.0.2 accelerate-1.2.1 bitsandbytes-0.45.0 charset-normalizer-3.4.1 filelock-3.16.1 fsspec-2024.12.0 huggingface-hub-0.27.0 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 packaging-24.2 peft-0.14.0 psutil-6.1.1 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.4.5 sympy-1.13.1 tokenizers-0.21.0 torch-2.5.1 tqdm-4.67.1 transformers-4.47.1 triton-3.1.0 urllib3-2.3.0
# Saving image...
# Image saved, took 3.38s
# Built image im-4gmuRjAqSjaZbr0g87mGf3 in 67.34s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/pricer_ephemeral.py
# ├── 🔨 Created mount PythonPackage:hello
# ├── 🔨 Created mount PythonPackage:llama
# └── 🔨 Created function price.
# Output()
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading shards:  25%|██▌       | 1/4 [01:58<05:55, 118.64s/it]
# Downloading shards:  50%|█████     | 2/4 [03:57<03:57, 118.89s/it]
# Downloading shards:  75%|███████▌  | 3/4 [05:54<01:57, 117.91s/it]
# Downloading shards: 100%|██████████| 4/4 [06:22<00:00, 82.29s/it] Downloading shards: 100%|██████████| 4/4 [06:22<00:00, 95.53s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:07<00:21,  7.15s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:14<00:14,  7.45s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:21<00:07,  7.23s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:23<00:00,  5.10s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:23<00:00,  5.90s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/akey7/main/ap-cbFbKxdFPSMmWfSKFGpsbK
# 133.0

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note:
#
# On the next line, I call `modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, simply use an Anaconda Prompt window or a Powershell instead, with your environment activated, and type `modal deploy pricer_service` there. Follow the same approach the next time we do !modal deploy too.

# %%
# !modal deploy pricer_service

# %%
pricer = modal.Function.lookup("pricer-service", "price")

# %%
pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")

# %%
# You can also run "modal deploy pricer_service2" at the command line in an activated environment
# !modal deploy pricer_service2
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount
#     /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py: Finalizing
# Building image im-fPsOmUdm5HL8GuWALX1jVi
# ⠴ Creating objects...
# ⠦ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# a/Projects/llm_engineering/week8/pricer_service2.py
# => Step 0: FROM base
# ⠇ Creating objects...
# 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# ⠇ Creating objects...
# ⠏ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# ⠋ Creating objects...
# ⠹ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# Collecting accelerateering/week8/pricer_service2.py
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# ⠹ Creating objects...
# Collecting bitsandbytesUsers/alicia/Projects/llm_engineering/week8/pricer_service
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# ⠹ Creating objects...
# Collecting huggingface/Users/alicia/Projects/llm_engineering/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# ⠼ Creating objects...
# Collecting peft mount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# ⠼ Creating objects...
# Collecting torchmount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# ⠼ Creating objects...
# Collecting transformersUsers/alicia/Projects/llm_engineering/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.1-py3-none-any.whl.metadata (44 kB)
# ⠼ Creating objects...
# ⠴ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# Collecting numpy<3.0.0,>=1.17 (from accelerate)2.py
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ⠋ Creating objects...
# Collecting packaging>=20.0 (from accelerate)/llm_engineering/week8/pricer_service
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# ⠋ Creating objects...
# Collecting psutil (from accelerate)/Projects/llm_engineering/week8/pricer_service
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# ⠋ Creating objects...
# Collecting pyyaml (from accelerate)/Projects/llm_engineering/week8/pricer_service
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ⠋ Creating objects...
# Collecting huggingface-hub>=0.21.0 (from accelerate)ineering/week8/pricer_service
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# ⠋ Creating objects...
# ⠙ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# Collecting safetensors>=0.4.3 (from accelerate)2.py
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# ⠙ Creating objects...
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.11/site-packages (from bitsandbytes) (4.12.2)
# ⠙ Creating objects...
# Collecting tqdm (from peft)s/alicia/Projects/llm_engineering/week8/pricer_service
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ⠹ Creating objects...
# Collecting filelock (from torch)cia/Projects/llm_engineering/week8/pricer_service
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# ⠹ Creating objects...
# Collecting networkx (from torch)cia/Projects/llm_engineering/week8/pricer_service
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ⠸ Creating objects...
# Collecting jinja2 (from torch)licia/Projects/llm_engineering/week8/pricer_service
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# ⠸ Creating objects...
# Collecting fsspec (from torch)licia/Projects/llm_engineering/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# ⠼ Creating objects...
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)ring/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠼ Creating objects...
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)ng/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠼ Creating objects...
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)ring/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ⠼ Creating objects...
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)gineering/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ⠼ Creating objects...
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)ineering/week8/pricer_service
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠼ Creating objects...
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)gineering/week8/pricer_service
# ⠼ Creating objects...
# ⠼ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠦ Creating objects...
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)eering/week8/pricer_service
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠦ Creating objects...
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)eering/week8/pricer_service
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ⠦ Creating objects...
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)ring/week8/pricer_service
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ⠦ Creating objects...
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)_engineering/week8/pricer_service
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ⠦ Creating objects...
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)ngineering/week8/pricer_service
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# ⠦ Creating objects...
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)ering/week8/pricer_service
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠦ Creating objects...
# Collecting triton==3.1.0 (from torch)rojects/llm_engineering/week8/pricer_service
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# ⠧ Creating objects...
# Collecting sympy==1.13.1 (from torch)rojects/llm_engineering/week8/pricer_service
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ⠧ Creating objects...
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)ing/week8/pricer_service
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ⠧ Creating objects...
# ⠇ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# Collecting regex!=2019.12.17 (from transformers).py
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# ⠸ Creating objects...
# Collecting requests (from transformers)jects/llm_engineering/week8/pricer_service
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ⠸ Creating objects...
# Collecting tokenizers<0.22,>=0.21 (from transformers)neering/week8/pricer_service
# ⠼ Creating objects...
# ⠼ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ⠴ Creating objects...
# Collecting MarkupSafe>=2.0 (from jinja2->torch)m_engineering/week8/pricer_service
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# ⠴ Creating objects...
# Collecting charset-normalizer<4,>=2 (from requests->transformers)8/pricer_service
# ⠧ Creating objects...
# ⠧ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# ⠇ Creating objects...
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# ⠇ Creating objects...
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)g/week8/pricer_service
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# ⠇ Creating objects...
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl (336 kB)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
# ⠇ Creating objects...
# ⠏ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 452.8 MB/s eta 0:00:00ce
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl (374 kB)
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# ⠋ Creating objects...
# ⠋ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 223.5 MB/s eta 0:00:00e
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# ⠸ Creating objects...
# ⠴ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 475.6 MB/s eta 0:00:00e
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# ⠸ Creating objects...
# ⠸ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 484.5 MB/s eta 0:00:00ce
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# ⠸ Creating objects...
# ⠸ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 484.4 MB/s eta 0:00:00ce
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 665.4 MB/s eta 0:00:00
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# ⠸ Creating objects...
# ⠼ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 465.6 MB/s eta 0:00:00e
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# ⠹ Creating objects...
# ⠸ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 474.3 MB/s eta 0:00:00e
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# ⠧ Creating objects...
# ⠧ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 471.3 MB/s eta 0:00:00ce
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# ⠇ Creating objects...
# ⠋ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠹ Creating objects..._service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 446.5 MB/s eta 0:00:00e
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# ⠹ Creating objects...
# ⠸ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 458.0 MB/s eta 0:00:00e
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# ⠇ Creating objects...
# ⠏ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠹ Creating objects..._service2.py
# ⠹ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 470.8 MB/s eta 0:00:00
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# ⠸ Creating objects...
# ⠸ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 481.0 MB/s eta 0:00:00ce
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# ⠸ Creating objects...
# ⠸ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 491.0 MB/s eta 0:00:00vice
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# ⠸ Creating objects...
# ⠦ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 344.6 MB/s eta 0:00:00e
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.1-py3-none-any.whl (10.1 MB)
# ⠹ Creating objects...
# ⠹ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 472.5 MB/s eta 0:00:00ce
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.12.0-py3-none-any.whl (183 kB)
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# ⠹ Creating objects...
# ⠹ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠸ Creating objects..._service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 364.9 MB/s eta 0:00:00ce
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# ⠸ Creating objects...
# ⠸ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 875.1 MB/s eta 0:00:00e
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# ⠸ Creating objects...
# ⠸ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 340.7 MB/s eta 0:00:00e
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# ⠸ Creating objects...
# ⠸ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 491.5 MB/s eta 0:00:00vice
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
# ⠸ Creating objects...
# ⠸ Creating objects...jects/llm_engineering/week8/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 578.1 MB/s eta 0:00:00vice
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# ⠸ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.0 GB/s eta 0:00:00ce
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl (128 kB)
# ⠸ Creating objects...
# ⠴ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# Installing collected packages: mpmath, huggingface, urllib3, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, triton, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# ⠴ Creating objects...
# ⠧ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# Successfully installed MarkupSafe-3.0.2 accelerate-1.2.1 bitsandbytes-0.45.0 charset-normalizer-3.4.1 filelock-3.16.1 fsspec-2024.12.0 huggingface-0.0.1 huggingface-hub-0.27.0 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 packaging-24.2 peft-0.14.0 psutil-6.1.1 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.4.5 sympy-1.13.1 tokenizers-0.21.0 torch-2.5.1 tqdm-4.67.1 transformers-4.47.1 triton-3.1.0 urllib3-2.3.0
# ⠏ Creating objects...
# ⠙ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# Saving image...engineering/week8/pricer_service2.py
# ⠴ Creating objects...
# ⠧ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠋ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━ 2.3/5.8 GB 0:00:00
# ⠋ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━ 3.9/5.8 GB 0:00:00
# ⠸ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.8/5.8 GB 0:00:00
# ⠦ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.8/5.8 GB 0:00:00
# ⠏ Creating objects...
# └── 🔨 Created mount
# ⠹ Creating objects...pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# Image saved, took 3.76sing/week8/pricer_service2.py
# ⠙ Creating objects...
# 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# Built image im-fPsOmUdm5HL8GuWALX1jVi in 70.85s
# ⠙ Creating objects...
# ⠙ Creating objects...ers/alicia/Projects/llm_engineering/week8/pricer_service
# └── 🔨 Created mount
# ⠴ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...g/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...g/week8/pricer_service2.py
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...model_to_folder...
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# Building image im-VXqIDHZfJ8OaPfUHmB5sYF
# ⠦ Creating objects...
# ├── 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# Created function Pricer.download_model_to_folder.
# => Step 0: running function 'Pricer.download_model_to_folder'
# ⠦ Creating objects...
# ├── 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# ⠏ Creating objects...ownload_model_to_folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# Pricer.download_model_to_folder.
# ⠇ Creating objects...
# ├── 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# ⠙ Creating objects...ownload_model_to_folder.
# ├── 🔨 Created mount
# ...
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# Image saved, took 79.32s_folder.
# ⠏ Creating objects...
# ├── 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# ⠏ Creating objects...ownload_model_to_folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# Finished image build for im-VXqIDHZfJ8OaPfUHmB5sYF
# ⠏ Creating objects...
# ├── 🔨 Created mount /Users/alicia/Projects/llm_engineering/week8/pricer_service
# ⠹ Creating objects...ownload_model_to_folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...folder.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# ⠴ Creating objects...
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/alicia/Projects/llm_engineering/week8/pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 562.432s! 🎉
#
# View Deployment: https://modal.com/apps/akey7/main/deployed/pricer-service

# %%
Pricer = modal.Cls.lookup("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 133.0

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# A student mentioned to me that he was concerned by how slow Modal seems to be. The reason is that Modal puts our service to sleep if we don't use it, and then it takes 2.5 minutes to spin back up.
#
# I've added a utility called `keep_warm.py` that will keep our Modal warm by pinging it every 30 seconds.
#
# To use the utliity, bring up a new Terminal (Mac) or Anaconda prompt (Windows), ensure the environment is activated with `conda activate llms`
#
# Then run: `python keep_warm.py` from within the week8 drectory.
#
# Remember to press ctrl+C or exit the window when you no longer need Modal running.

# %% [markdown]
# ## And now introducing our Agent class

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# 299.0
