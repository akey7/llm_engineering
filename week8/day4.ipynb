# %% [markdown]
# # The Price is Right
#
# First we'll polish off 2 more simple agents:
#
# The **Messaging Agent** to send push notifications
#
# The **Planning Agent** to coordinate activities
#
# Then we'll put it all together into an Agent Framework.
#
# For the Push Notification, we will be using a nifty platform called Pushover.
# You'll need to set up a free account and add 2 tokens to your `.env` file:
#
# ```
# PUSHOVER_USER=xxx
# PUSHOVER_TOKEN=xxx
# ```

# %%
from dotenv import load_dotenv
from agents.messaging_agent import MessagingAgent

# %%
load_dotenv()
DB = "/Volumes/BlueData/autonomous_agent_system/vectorstore"

# %%
agent = MessagingAgent()

# %%
agent.push("MASSIVE NEWS!!!")

# %%
import chromadb
DB = "products_vectorstore"
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')
from agents.planning_agent import PlanningAgent

# %%
planner = PlanningAgent(collection)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 planner = PlanningAgent(collection)
#
# File ~/Projects/llm_engineering/week8/agents/planning_agent.py:21, in PlanningAgent.__init__(self, collection)
#      19 self.log("Planning Agent is initializing")
#      20 self.scanner = ScannerAgent()
# ---> 21 self.ensemble = EnsembleAgent(collection)
#      22 self.messenger = MessagingAgent()
#      23 self.log("Planning Agent is ready")
#
# File ~/Projects/llm_engineering/week8/agents/ensemble_agent.py:22, in EnsembleAgent.__init__(self, collection)
#      20 self.log("Initializing Ensemble Agent")
#      21 self.specialist = SpecialistAgent()
# ---> 22 self.frontier = FrontierAgent(collection)
#      23 self.random_forest = RandomForestAgent()
#      24 self.model = joblib.load('/Volumes/BlueData/autonomous_agent_system/ensemble_model.pkl')
#
# File ~/Projects/llm_engineering/week8/agents/frontier_agent.py:32, in FrontierAgent.__init__(self, collection)
#      30 self.openai = OpenAI()
#      31 self.collection = collection
# ---> 32 self.model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
#      33 self.log("Frontier Agent is ready")
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:308, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     299         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     301 if is_sentence_transformer_model(
#     302     model_name_or_path,
#     303     token,
#    (...)
#     306     local_files_only=local_files_only,
#     307 ):
# --> 308     modules, self.module_kwargs = self._load_sbert_model(
#     309         model_name_or_path,
#     310         token=token,
#     311         cache_folder=cache_folder,
#     312         revision=revision,
#     313         trust_remote_code=trust_remote_code,
#     314         local_files_only=local_files_only,
#     315         model_kwargs=model_kwargs,
#     316         tokenizer_kwargs=tokenizer_kwargs,
#     317         config_kwargs=config_kwargs,
#     318     )
#     319 else:
#     320     modules = self._load_auto_model(
#     321         model_name_or_path,
#     322         token=token,
#    (...)
#     329         config_kwargs=config_kwargs,
#     330     )
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1728, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    1725 # Try to initialize the module with a lot of kwargs, but only if the module supports them
#    1726 # Otherwise we fall back to the load method
#    1727 try:
# -> 1728     module = module_class(model_name_or_path, cache_dir=cache_folder, backend=self.backend, **kwargs)
#    1729 except TypeError:
#    1730     module = module_class.load(model_name_or_path)
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:82, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#      80 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#      81     tokenizer_args["model_max_length"] = max_seq_length
# ---> 82 self.tokenizer = AutoTokenizer.from_pretrained(
#      83     tokenizer_name_or_path if tokenizer_name_or_path is not None else model_name_or_path,
#      84     cache_dir=cache_dir,
#      85     **tokenizer_args,
#      86 )
#      88 # No max_seq_length set. Try to infer from model
#      89 if max_seq_length is None:
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:858, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     855     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     857 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# --> 858 tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#     859 if "_commit_hash" in tokenizer_config:
#     860     kwargs["_commit_hash"] = tokenizer_config["_commit_hash"]
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:690, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, **kwargs)
#     687     token = use_auth_token
#     689 commit_hash = kwargs.get("_commit_hash", None)
# --> 690 resolved_config_file = cached_file(
#     691     pretrained_model_name_or_path,
#     692     TOKENIZER_CONFIG_FILE,
#     693     cache_dir=cache_dir,
#     694     force_download=force_download,
#     695     resume_download=resume_download,
#     696     proxies=proxies,
#     697     token=token,
#     698     revision=revision,
#     699     local_files_only=local_files_only,
#     700     subfolder=subfolder,
#     701     _raise_exceptions_for_gated_repo=False,
#     702     _raise_exceptions_for_missing_entries=False,
#     703     _raise_exceptions_for_connection_errors=False,
#     704     _commit_hash=commit_hash,
#     705 )
#     706 if resolved_config_file is None:
#     707     logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/transformers/utils/hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/file_download.py:862, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     842     return _hf_hub_download_to_local_dir(
#     843         # Destination
#     844         local_dir=local_dir,
#    (...)
#     859         local_files_only=local_files_only,
#     860     )
#     861 else:
# --> 862     return _hf_hub_download_to_cache_dir(
#     863         # Destination
#     864         cache_dir=cache_dir,
#     865         # File info
#     866         repo_id=repo_id,
#     867         filename=filename,
#     868         repo_type=repo_type,
#     869         revision=revision,
#     870         # HTTP info
#     871         endpoint=endpoint,
#     872         etag_timeout=etag_timeout,
#     873         headers=headers,
#     874         proxies=proxies,
#     875         token=token,
#     876         # Additional options
#     877         local_files_only=local_files_only,
#     878         force_download=force_download,
#     879     )
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/file_download.py:925, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#     921         return pointer_path
#     923 # Try to get metadata (etag, commit_hash, url, size) from the server.
#     924 # If we can't, a HEAD request error is returned.
# --> 925 (url_to_download, etag, commit_hash, expected_size, head_call_error) = _get_metadata_or_catch_error(
#     926     repo_id=repo_id,
#     927     filename=filename,
#     928     repo_type=repo_type,
#     929     revision=revision,
#     930     endpoint=endpoint,
#     931     proxies=proxies,
#     932     etag_timeout=etag_timeout,
#     933     headers=headers,
#     934     token=token,
#     935     local_files_only=local_files_only,
#     936     storage_folder=storage_folder,
#     937     relative_filename=relative_filename,
#     938 )
#     940 # etag can be None for several reasons:
#     941 # 1. we passed local_files_only.
#     942 # 2. we don't have a connection
#    (...)
#     948 # If the specified revision is a commit hash, look inside "snapshots".
#     949 # If the specified revision is a branch or tag, look inside "refs".
#     950 if head_call_error is not None:
#     951     # Couldn't make a HEAD call => let's try to find a local file
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/file_download.py:1376, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1374 try:
#    1375     try:
# -> 1376         metadata = get_hf_file_metadata(
#    1377             url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token
#    1378         )
#    1379     except EntryNotFoundError as http_error:
#    1380         if storage_folder is not None and relative_filename is not None:
#    1381             # Cache the non-existence of the file
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/file_download.py:1296, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1293 headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1295 # Retrieve metadata
# -> 1296 r = _request_wrapper(
#    1297     method="HEAD",
#    1298     url=url,
#    1299     headers=headers,
#    1300     allow_redirects=False,
#    1301     follow_relative_redirects=True,
#    1302     proxies=proxies,
#    1303     timeout=timeout,
#    1304 )
#    1305 hf_raise_for_status(r)
#    1307 # Return
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/file_download.py:277, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     275 # Recursively follow relative redirects
#     276 if follow_relative_redirects:
# --> 277     response = _request_wrapper(
#     278         method=method,
#     279         url=url,
#     280         follow_relative_redirects=False,
#     281         **params,
#     282     )
#     284     # If redirection, we redirect only relative paths.
#     285     # This is useful in case of a renamed repository.
#     286     if 300 <= response.status_code <= 399:
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/file_download.py:300, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     297     return response
#     299 # Perform request and return if status_code is not in the retry list.
# --> 300 response = get_session().request(method=method, url=url, **params)
#     301 hf_raise_for_status(response)
#     302 return response
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:93, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      91 """Catch any RequestException to append request id to the error message for debugging."""
#      92 try:
# ---> 93     return super().send(request, *args, **kwargs)
#      94 except requests.RequestException as e:
#      95     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/llms/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/miniconda3/envs/llms/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/miniconda3/envs/llms/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/llms/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~/miniconda3/envs/llms/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/llms/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
planner.plan()
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/synchronicity/synchronizer.py:336, in Synchronizer._run_function_sync(self, coro, original_func)
#     335 try:
# --> 336     value = fut.result()
#     337 except concurrent.futures.CancelledError as expected_cancellation:
#     338     # we *expect* this cancellation, but defer to the passed coro to potentially
#     339     # intercept and treat the cancellation some other way
#
# File ~/miniconda3/envs/llms/lib/python3.11/concurrent/futures/_base.py:454, in Future.result(self, timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
# --> 454     raise CancelledError()
#     455 elif self._state == FINISHED:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 planner.plan()
#
# File ~/Projects/llm_engineering/week8/agents/planning_agent.py:49, in PlanningAgent.plan(self, memory)
#      47 selection = self.scanner.scan(memory=memory)
#      48 if selection:
# ---> 49     opportunities = [self.run(deal) for deal in selection.deals[:5]]
#      50     opportunities.sort(key=lambda opp: opp.discount, reverse=True)
#      51     best = opportunities[0]
#
# File ~/Projects/llm_engineering/week8/agents/planning_agent.py:49, in <listcomp>(.0)
#      47 selection = self.scanner.scan(memory=memory)
#      48 if selection:
# ---> 49     opportunities = [self.run(deal) for deal in selection.deals[:5]]
#      50     opportunities.sort(key=lambda opp: opp.discount, reverse=True)
#      51     best = opportunities[0]
#
# File ~/Projects/llm_engineering/week8/agents/planning_agent.py:32, in PlanningAgent.run(self, deal)
#      26 """
#      27 Run the workflow for a particular deal
#      28 :param deal: the deal, summarized from an RSS scrape
#      29 :returns: an opportunity including the discount
#      30 """
#      31 self.log("Planning Agent is pricing up a potential deal")
# ---> 32 estimate = self.ensemble.price(deal.product_description)
#      33 discount = estimate - deal.price
#      34 self.log(f"Planning Agent has processed a deal with discount ${discount:.2f}")
#
# File ~/Projects/llm_engineering/week8/agents/ensemble_agent.py:36, in EnsembleAgent.price(self, description)
#      28 """
#      29 Run this ensemble model
#      30 Ask each of the models to price the product
#    (...)
#      33 :return: an estimate of its price
#      34 """
#      35 self.log("Running Ensemble Agent - collaborating with specialist, frontier and random forest agents")
# ---> 36 specialist = self.specialist.price(description)
#      37 frontier = self.frontier.price(description)
#      38 random_forest = self.random_forest.price(description)
#
# File ~/Projects/llm_engineering/week8/agents/specialist_agent.py:27, in SpecialistAgent.price(self, description)
#      23 """
#      24 Make a remote call to return the estimate of the price of this item
#      25 """
#      26 self.log("Specialist Agent is calling remote fine-tuned model")
# ---> 27 result = self.pricer.price.remote(description)
#      28 self.log(f"Specialist Agent completed - predicting ${result:.2f}")
#      29 return result
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/synchronicity/synchronizer.py:592, in Synchronizer._wrap_proxy_method.<locals>.proxy_method(self, *args, **kwargs)
#     590 instance = self.__dict__[synchronizer_self._original_attr]
#     591 try:
# --> 592     return wrapped_method(instance, *args, **kwargs)
#     593 except UserCodeException as uc_exc:
#     594     uc_exc.exc.__suppress_context__ = True
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/synchronicity/combined_types.py:26, in FunctionWithAio.__call__(self, *args, **kwargs)
#      20 def __call__(self, *args, **kwargs):
#      21     # .__call__ is special - it's being looked up on the class instead of the instance when calling something,
#      22     # so setting the magic method from the constructor is not possible
#      23     # https://stackoverflow.com/questions/22390532/object-is-not-callable-after-adding-call-method-to-instance
#      24     # so we need to use an explicit wrapper function here
#      25     try:
# ---> 26         return self._func(*args, **kwargs)
#      27     except UserCodeException as uc_exc:
#      28         uc_exc.exc.__suppress_context__ = True
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/synchronicity/synchronizer.py:510, in Synchronizer._wrap_callable.<locals>.f_wrapped(*args, **kwargs)
#     507 elif interface == Interface.BLOCKING:
#     508     # This is the exit point, so we need to unwrap the exception here
#     509     try:
# --> 510         return self._run_function_sync(res, f)
#     511     except StopAsyncIteration:
#     512         # this is a special case for handling __next__ wrappers around
#     513         # __anext__ that raises StopAsyncIteration
#     514         raise StopIteration()
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/synchronicity/synchronizer.py:341, in Synchronizer._run_function_sync(self, coro, original_func)
#     337     except concurrent.futures.CancelledError as expected_cancellation:
#     338         # we *expect* this cancellation, but defer to the passed coro to potentially
#     339         # intercept and treat the cancellation some other way
#     340         expected_cancellation.__suppress_context__ = True
# --> 341         raise exc  # if cancel - re-raise the original KeyboardInterrupt again
#     343 if getattr(original_func, self._output_translation_attr, True):
#     344     return self._translate_out(value)
#
# File ~/miniconda3/envs/llms/lib/python3.11/site-packages/synchronicity/synchronizer.py:325, in Synchronizer._run_function_sync(self, coro, original_func)
#     321 while 1:
#     322     try:
#     323         # poll every second to give Windows a chance to abort on Ctrl-C
#     324         #
# --> 325         value = fut.result(timeout=0.1)
#     326         break
#     327     except concurrent.futures.TimeoutError:
#
# File ~/miniconda3/envs/llms/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/llms/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
